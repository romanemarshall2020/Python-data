# %%
import torch

# %%
x = torch.rand(5, 3, 76, 543, 89)
print(x)
# Out:
# tensor([[[[[5.8663e-01, 4.7100e-01, 5.5062e-01,  ..., 3.0297e-01,
#             4.9909e-01, 2.5342e-01],
#            [8.8696e-01, 1.7117e-01, 4.0807e-01,  ..., 6.6630e-01,
#             5.6493e-01, 6.7753e-01],
#            [8.8617e-01, 9.2531e-01, 5.0709e-01,  ..., 9.5976e-01,
#             1.2022e-01, 7.2132e-02],
#            ...,
#            [1.8940e-01, 7.5405e-01, 5.7750e-01,  ..., 7.0301e-01,
#             4.2789e-01, 5.1844e-01],
#            [5.0842e-01, 6.9816e-01, 4.6186e-01,  ..., 8.9493e-01,
#             9.8239e-01, 1.6884e-01],
#            [2.5611e-01, 3.4657e-01, 7.9912e-01,  ..., 5.2689e-01,
#             3.0995e-02, 7.4352e-01]],
#
#           [[1.5810e-01, 1.3963e-01, 4.6831e-01,  ..., 3.9208e-01,
#             8.6669e-01, 8.8990e-05],
#            [4.1252e-01, 8.8723e-02, 2.3082e-01,  ..., 6.5699e-01,
#             7.6322e-01, 5.1543e-01],
#            [6.5709e-01, 6.8331e-01, 5.2079e-01,  ..., 7.7989e-01,
#             7.4537e-02, 5.0995e-01],
# ...

# %%
torch.cuda.is_available()
# Out:
# True
